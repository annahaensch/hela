# %%
import pandas as pd
import numpy as np

import altair as alt
import hela.visualization.hmm as hmmplot
import matplotlib.pyplot as plt
# %matplotlib inline

from hela import hmm
import hela.generation.hmm as gen
from scipy.special import logsumexp

from datetime import datetime
from dask.distributed import Client

TU_COLORS = [
    "#9b67ff", "#57b3c2", "#ffa040", "#ff6283", "#2ccc72", "#1270cb", "#bd043a",
    "#a1c54d", "#4c319e", "#c6c0fe", "#195036", "#f6a39f"
]

# %%
generative_model = gen.DiscreteHMMGenerativeModel(
                                     n_hidden_states =3,
                                     n_gaussian_features=2,
                                    n_categorical_features = 2,
                                     n_gmm_components = 1)

# %%
hidden_states = generative_model.generate_hidden_state_sequence(n_observations = 1000)
hmmplot.draw_states(hidden_states, hide_brush=False)

# %%
hmm_data = generative_model.generate_observations(hidden_states)
hmm_data.head()
# Out:
#             categorical_feature_0  categorical_feature_1  gaussian_feature_0  \
# 2020-08-01                      0                      0           -1.082649
# 2020-08-02                      0                      0           -1.801145
# 2020-08-03                      0                      0           -0.598852
# 2020-08-04                      0                      0           -3.085389
# 2020-08-05                      0                      0           -3.982638
#
#             gaussian_feature_1
# 2020-08-01           -3.350566
# 2020-08-02           -1.828712
# 2020-08-03           -3.457630
# 2020-08-04           -3.157730
# 2020-08-05           -2.193321

# %%
def plot_hidden_states(data, hidden_states,means, title):
    plt.figure(figsize = (8,8))
    for i in range(generative_model.n_hidden_states):
        idx = data[hidden_states == i].index
        plt.scatter(data.loc[idx,'gaussian_feature_0'], 
                    data.loc[idx,'gaussian_feature_1'], 
                    color = TU_COLORS[i],
                    label = "hidden state {}".format(i))
    for i in range(len(means)):
        plt.scatter(means[i][0][0], 
                    means[i][0][1], 
                    color = "black", 
                    marker = "x")

    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.xlabel('gaussian_feature_0')
    plt.ylabel('gaussian_feature_1')
    plt.title(title)
    plt.show()
    
plot_hidden_states(hmm_data,hidden_states,generative_model.means,"Hidden State Assignments for Gaussian Data")

# %%
training_spec = gen.data_to_discrete_hmm_training_spec(hidden_states=hidden_states, 
                                       n_hidden_states=generative_model.n_hidden_states, 
                                       data=hmm_data, 
                                       categorical_features = None,#list(generative_model.categorical_values.columns),
                                       gaussian_features=list(generative_model.gaussian_values.columns),
                                       n_gmm_components=1)

training_spec
# Out:
# {'hidden_state': {'type': 'finite', 'count': 3},
#  'observations': [{'name': 'gaussian_feature_0',
#    'type': 'continuous',
#    'dist': 'gaussian',
#    'dims': 1},
#   {'name': 'gaussian_feature_1',
#    'type': 'continuous',
#    'dist': 'gaussian',
#    'dims': 1}],
#  'model_parameter_constraints': {'transition_constraints': array([[0.50299401, 0.49700599, 0.        ],
#          [0.        , 0.53739612, 0.46260388],
#          [0.54605263, 0.        , 0.45394737]]),
#   'initial_state_constraints': array([0., 1., 0.]),
#   'gmm_parameter_constraints': {'n_gmm_components': 1,
#    'means': array([[[-0.90899499,  0.20171063]],
#
#           [[-1.31093581, -2.0758891 ]],
#
#           [[ 0.18887925, -1.68027013]]]),
#    'covariances': array([[[[ 2.48609715, -0.41637208],
#             [-0.41637208,  5.98970548]]],
#
#
#           [[[ 3.42619453, -0.1469799 ],
#             [-0.1469799 ,  4.49967284]]],
#
#
#           [[[ 4.05427811, -1.06371106],
#             [-1.06371106,  5.67195712]]]]),
#    'component_weights': array([[1.],
#           [1.],
#           [1.]])}}}

# %%
model_config = hmm.DiscreteHMMConfiguration.from_spec(training_spec)
model_config.model_type
# Out:
# 'DiscreteHMM'

# %%
untrained_model = model_config.to_model()

# %%
# Load learning algorithm.
alg = hmm.LearningAlgorithm()

# Train model.
n_em_iterations = 10
model = alg.run(untrained_model, hmm_data, n_em_iterations)

# Print training results.
from scipy.special import logsumexp 

alphas = []
for s in alg.sufficient_statistics:
    s_inf = s.model.load_inference_interface()
    s_log_prob = s_inf.predict_hidden_state_log_probability(hmm_data)
    alpha = s_inf._compute_forward_probabilities(s_log_prob)
    alphas.append(logsumexp(alpha[-1]))
    
plt.figure(figsize = (15,5))
plt.scatter([x for x in range(len(alphas))],alphas, color = "#ffa040")

plt.title("Observed Data Log Likelihood")
plt.ylabel("Log likelihood")
plt.xlabel("Iteration Number")
plt.show()

# %%
inf = model.load_inference_interface()
viterbi_predict = inf.predict_hidden_states_viterbi(hmm_data)
prop_correct = hidden_states[viterbi_predict == hidden_states].shape[0] / hidden_states.shape[0]
print("Viterbi proportion of correctly assigned hidden states: {}".format(prop_correct))

hmmplot.draw_states(viterbi_predict, hide_brush=False)
# Out:
# Viterbi proportion of correctly assigned hidden states: 0.986

# %%
plot_hidden_states(hmm_data,viterbi_predict,generative_model.means, "Hidden State Assignments with Viterbi Prediction")

# %%
# i = 100 #Ideally this should be very large.
# gibbs_predict = inf.predict_hidden_states_gibbs(data = hmm_data,n_iterations = i)

# prop_correct = hidden_states[gibbs_predict == hidden_states].shape[0] / hidden_states.shape[0]
# print("Gibbs proportion of correctly assigned hidden states with {} iterations: {}".format(i,prop_correct))

# hmmplot.draw_states(gibbs_predict, hide_brush=False)

# %%
# def predict_hidden_states_gibbs(self,
#                         data,
#                         n_iterations=5,
#                         seed_inference=None):
# """ Returns most likely sequence of hidden states using Gibbs sampling.

model = inf.model
seed_inference = None
data = hmm_data
initial_state_prob = np.exp(model.log_initial_state)
emission_prob = np.exp(
    np.array(inf.predict_hidden_state_log_probability(data)))
emission_prob = emission_prob / np.sum(
    emission_prob, axis=1).reshape(-1, 1)
transition_prob = np.exp(model.log_transition)

# %%
fgm = gen.FactoredHMMGenerativeModel(
                                 ns_hidden_states =[2,2,2],
                                 n_gaussian_features = 3,
                                 n_categorical_features = 1)

fgm.emission_matrix
# Out:
# array([[0.76775901, 0.95815496, 0.99465459, 0.05486771, 0.78583832,
#         0.14633452, 0.13596242, 0.90440887],
#        [0.23224099, 0.04184504, 0.00534541, 0.94513229, 0.21416168,
#         0.85366548, 0.86403758, 0.09559113]])

# %%
fgm.initial_state_vector
# Out:
# array([1, 0, 0])

# %%
# Random init
if seed_inference is None:
    hidden_states = pd.Series(
        np.random.choice(range(model.n_hidden_states), data.shape[0]),
        index=data.index)
    hidden_states.iloc[0] = np.argmax(initial_state_prob)
# else:
# hidden_states = seed_inference.copy()
# na_index = seed_inference[seed_inference.isna()]
# if na_index.shape[0] > 0:
#     hidden_states.loc[na_index] = np.random.choice(
#         range(model.n_hidden_states), na_index.shape[0])

for i in range(2):
    sampling_parameter = np.random.uniform(0, 1, data.shape[0])
    sampling_order = np.random.choice(
        data.index.shape[0], len(data.index), replace=False)
    for t in sampling_order:
        if t == 0:
            next_state = hidden_states.iloc[1]
            updated_state_prob = initial_state_prob * emission_prob[
                t] * transition_prob[:, next_state]

        elif t == hidden_states.shape[0] - 1:
            previous_state = hidden_states.iloc[t - 1]
            current_state = hidden_states.iloc[t]
            updated_state_prob = transition_prob[
                previous_state] * emission_prob[t]

        else:
            previous_state = hidden_states.iloc[t - 1]
            current_state = hidden_states.iloc[t]
            next_state = hidden_states.iloc[t + 1]
            updated_state_prob = transition_prob[
                previous_state] * emission_prob[
                    t] * transition_prob[:, next_state]

        if np.sum(updated_state_prob) == 0:
            print("true")
            updated_state_prob = np.full(len(updated_state_prob), 1)
        updated_state_prob = updated_state_prob / np.sum(
            updated_state_prob)
        print(updated_state_prob)
        cumulative_prob = np.cumsum(updated_state_prob)
        print(cumulative_prob)
        updated_state = np.where(
            cumulative_prob >= sampling_parameter[t])[0][0]
        hidden_states.iloc[t] = updated_state

# return hidden_states
# Out:
# 2020-08-01    1
# 2020-08-02    0
# 2020-08-03    1
# 2020-08-04    2
# 2020-08-05    0
#              ..
# 2023-04-23    1
# 2023-04-24    0
# 2023-04-25    0
# 2023-04-26    2
# 2023-04-27    0
# Freq: D, Length: 1000, dtype: int64
